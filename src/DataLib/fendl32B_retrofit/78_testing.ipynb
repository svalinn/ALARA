# %%
import urllib.request
import urllib.error
import aiohttp
import asyncio


def urllib_download(download_url, filetype):
    """
    Use the urllib Request and Error packages to download the contents of
        a webpage, if it exists
    
    Arguments:
        download_url (str): Link to the webpage to download the desired file.
        filetype (str): Either "ENDF" or "PENDF" filetypes to be downloaded
            (case insensitive).
    """

    try:
        with urllib.request.urlopen(download_url) as f:
            temp_file = f.read().decode('utf-8')
    except urllib.error.URLError as e:
        if e.code == 404:
            temp_file = None
            raise FileNotFoundError(f'{filetype.upper()} file does not exist at {download_url}')
    return temp_file

async def fetch(session, url):
    try:
        async with session.get(url) as response:
            if response.status == 200:
                return await response.text()
            else:
                return None
    except aiohttp.ClientError:
        return None

async def fetch_with_sem(semaphore, session, url):
    async with semaphore:
        return await fetch(session, url)

async def async_tendl_download(element, concurrency_limit = 50, iterate=True):
    downloads = []
    A_vals = []

    semaphore = asyncio.Semaphore(concurrency_limit)

    async with aiohttp.ClientSession() as session:
        tasks = []
        for A in range(1, 292):  # Adjusted to range from 1 to 291 (inclusive)
            for i in range(2):
                A_str = str(A).zfill(3)
                if i == 1:
                    A_str += 'm'

                isotope_component = f'{element}/{element}{A_str}/lib/endf/n-{element}{A_str}.'
                tendl_gen_url = 'https://tendl.web.psi.ch/tendl_2017/neutron_file/'
                tendl_url = tendl_gen_url + isotope_component + 'tendl'
                pendf_url = tendl_gen_url + isotope_component + 'pendf'

                tendl_task = fetch_with_sem(semaphore, session, tendl_url)
                pendf_task = fetch_with_sem(semaphore, session, pendf_url)

                tasks.append((tendl_task, pendf_task, tendl_url, pendf_url, A_str))

        results = await asyncio.gather(*[asyncio.gather(tendl_task, pendf_task) for tendl_task, pendf_task, _, _, _ in tasks])

        for (tendl_result, pendf_result), (tendl_task, pendf_task, tendl_url, pendf_url, A_str) in zip(results, tasks):
            if tendl_result and pendf_result:
                downloads.append((tendl_url, pendf_url))
                A_vals.append(A_str)
            elif not iterate:
                logger.error(FileNotFoundError())

    return A_vals

def download_tendl(element, A, filetype, save_path = None):
    """
    Download ENDF/PENDF files from the TENDL 2017 database for specific isotopes.

    Arguments:
        element (str): Chemical symbol for element of interest (i.e. Ti).
        A (str or int): Mass number for selected isotope (i.e. 48).
            If the target is an isomer, "m" after the mass number (i.e. 48m),
            so A must be input as a string.
        filetype (str): Either "ENDF" or "PENDF" filetypes to be downloaded
            (case insensitive).
        save_path (str, optional): User-defined file path for the downloaded file.
            Defaults to None and will be otherwise defined internally.
    
    Returns:
        save_path (str): File path for the file downloaded file.
    """

    # Ensure that A is properly formatted
    A = str(A).zfill(3)
#    if 'm' in A:
#        A += 'm'

    # Create a dictionary to generalize formatting for both ENDF and PENDF files
    file_handling = {'endf' : {'ext': 'tendl', 'tape_num': 20},
                     'pendf' : {'ext': 'pendf', 'tape_num': 21}}
    
    # Construct the filetype and isotope specific URL
    isotope_component = f'{element}/{element}{A}/lib/endf/n-{element}{A}.'
    ext = file_handling[filetype.lower()]['ext']
    tendl_gen_url = 'https://tendl.web.psi.ch/tendl_2017/neutron_file/'
    download_url = tendl_gen_url + isotope_component + ext
    print(f'{filetype.upper()} URL: {download_url}')

    # Define a save path for the file if there is not one already specified
    if save_path is None:
        save_path = f'tape{file_handling[filetype.lower()]["tape_num"]}'

    # Conditionally downloa
    temp_file = urllib_download(download_url, filetype)

    with open(save_path, 'w') as f:
        f.write(temp_file)

    return save_path

# %%
pendf_path = download_tendl('C', 13, 'pendf')
endf_path = download_tendl('C', 13, 'endf')
# Out:
# PENDF URL: https://tendl.web.psi.ch/tendl_2017/neutron_file/C/C013/lib/endf/n-C013.pendf
# ENDF URL: https://tendl.web.psi.ch/tendl_2017/neutron_file/C/C013/lib/endf/n-C013.tendl

# %%
import ENDFtk
def extract_endf_specs(path, filetype):
    """
    Extract the material ID and MT numbers from an ENDF or GENDF file.

    Arguments:
        path (str): File path to the selected ENDF/GENDF file.
        filetype (str): Either ENDF or GENDF (case insensitive)
    
    Returns:
        matb (int): Unique material ID extracted from the file.
        MTs (list): List of reaction types (MT's) present in the file.
        file (ENDFtk.tree.File or None): ENDFtk file object containing the contents
            for a specific material's cross-section data.
            Only returns the file for GENDF filetypes.
    """
    # Read in ENDF tape using ENDFtk
    tape = ENDFtk.tree.Tape.from_file(path)

    # Determine the material ID
    mat_ids = tape.material_numbers
    matb = mat_ids[0]

    # Set MF for cross sections
    xs_MF = 3

    # Extract out the file
    file = tape.material(matb).file(xs_MF)

    # Extract the MT numbers that are present in the file
    MTs = [MT.MT for MT in file.sections.to_list()]

    filetype = filetype.lower()
    return_values = {
        'endf': (matb, MTs),
        'gendf': (matb, MTs, file)
    }
    return return_values.get(filetype)

# %%
material_id, MTs = extract_endf_specs(endf_path, 'endf')

# %%
# Import packages
import subprocess

# Define constants
NENDF = 20 # unit for endf tape
NPEND = 21 # unit for pendf tape
NGOUT1 = 0 # unit for input gout tape (default=0)
NGOUT2 = 31 # unit for output gout tape (default=0)
IGN = 17 # neutron group structure option (corresponding to Vitamin J)
IGG = 0 # gamma group structure option
IWT = 11 # weight function option (corresponding to Vitamin E)
LORD = 0 # Legendre order
NTEMP = 1 # number of temperatures (default=1)
NSIGZ = 1 # number of sigma zeroes (default=1)
IPRINT = 1 # long print option (0/1=minimum/maximum) --(default=1)
ISMOOTH = 1 # switch on/off smoother operation (1/0, default=1=on)
TEMP = 293.16 # temperature in Kelvin
SIGZ = 0 # sigma zero values (including infinity)
MFD = 3 # file to be processed
MATD = 0 # next mat number to be processed

# Dictionary of elements in the Periodic Table
elements = [
    'H', 'He', 'Li', 'Be', 'B', 'C', 'N', 'O', 'F', 'Ne',
    'Na', 'Mg', 'Al', 'Si', 'P', 'S', 'Cl', 'Ar', 'K', 'Ca',
    'Sc', 'Ti', 'V', 'Cr', 'Mn', 'Fe', 'Co', 'Ni', 'Cu', 'Zn',
    'Ga', 'Ge', 'As', 'Se', 'Br', 'Kr', 'Rb', 'Sr', 'Y', 'Zr',
    'Nb', 'Mo', 'Tc', 'Ru', 'Rh', 'Pd', 'Ag', 'Cd', 'In', 'Sn',
    'Sb', 'Te', 'I', 'Xe', 'Cs', 'Ba', 'La', 'Ce', 'Pr', 'Nd',
    'Pm', 'Sm', 'Eu', 'Gd', 'Tb', 'Dy', 'Ho', 'Er', 'Tm', 'Yb',
    'Lu', 'Hf', 'Ta', 'W', 'Re', 'Os', 'Ir', 'Pt', 'Au', 'Hg',
    'Tl', 'Pb', 'Bi', 'Po', 'At', 'Rn', 'Fr', 'Ra', 'Ac', 'Th',
    'Pa', 'U', 'Np', 'Pu', 'Am', 'Cm', 'Bk', 'Cf', 'Es', 'Fm',
    'Md', 'No', 'Lr', 'Rf', 'Db', 'Sg', 'Bh', 'Hs', 'Mt', 'Ds',
    'Rg', 'Cn', 'Nh', 'Fl', 'Mc', 'Lv', 'Ts', 'Og'
]
elements = dict(zip(elements, range(1, len(elements)+1)))

def format_card(card_number, card_content, MTs):
    """
    Format individual "cards" for the NJOY input cards to run with GROUPR.
        Formatting and terminology based on the NJOY user manual:
        (https://github.com/njoy/NJOY2016-manual/raw/master/njoy16.pdf)

    Arguments:
        card_number (int): Individual identifier of "card" in input "deck".
        card_content (list): Values to be written on each individual "card".
        MTs (list): List of reaction types (MT's) present in the ENDF/PENDF files.
    
    Returns:
        card_str (str): Concatenated string of an individual "card's" contents. 
    """
    
    # Initialize string and concatenate contents of the card with it
    card_str = ''
    gen_str = ' ' + ' '.join(map(str, card_content))
    if card_number == 9:
        card_str = ' ' + '/\n '.join(card_content) + '/\n'
    elif card_number == 4:
        card_str += gen_str + '\n'
    else:
        card_str += gen_str + '/\n'
    return card_str

def groupr_input_file_format(matb, MTs, element, A, mt_dict):

    """"
    Format the input "deck" to run NJOY from individually formatted cards.
        Most parameters are predefined as constants, as necessary for a GROUPR run
        to write a group-wise file (GENDF) based on the ENDF and PENDF files
        with a Vitamin-J 175 group structure and a Vitamin-E weighting function.
        Other parameters are isotope specific, such as "matb", which corresponds
        to the NJOY naming convention for the material ID, which are separately
        extracted from the ENDF file to be referenced.

        Formatting and terminology based on the NJOY user manual:
        (https://github.com/njoy/NJOY2016-manual/raw/master/njoy16.pdf)

    Arguments:
        matb (int): Unique material ID extracted from the ENDF base file.
        MTs (list): List of reaction types (MT's) present in the ENDF/PENDF files.
        element (str): Chemical symbol for element of interest.
        A (str or int): Mass number for selected isotope.
            If the target is an isomer, "m" after the mass number,
            so A must be input as a string.
        mt_dict (dict): Reference dictionary containing reaction information
            for each MT number pre-defined in the ENDF manual.
            (https://www.oecd-nea.org/dbdata/data/manual-endf/endf102_MT.pdf)
    
    Returns:
        cards (dict): Dictionary containing each "card" identified by its card number.
    """

    cards = {}
    
    cards[1] = [NENDF, NPEND, NGOUT1, NGOUT2]
    # matb -- (already defined) -- material to be processed
    cards[2] = [matb, IGN, IGG, IWT, LORD, NTEMP, NSIGZ, IPRINT]
    Z = str(elements[element]).zfill(2)
    title = f'"{Z}-{element}-{A} for TENDL 2017"'
    cards[3] = [title]
    cards[4] = [TEMP]
    cards[5] = [SIGZ]
    mtd = MTs # sections to be processed
    cards[9] = []
    for MT in MTs:
        mtname = mt_dict[str(MT)] # description of section to be processed
        card9_line = f'{MFD} {MT} "{mtname}"'
        cards[9].append(card9_line)
    cards[10] = [MATD]

    return cards

def groupr_input_file_writer(cards, MTs):
    """"
    Write out the NJOY GROUPR input card by formatting each card line by line.

    Arguments:
        cards (dict): Dictionary containing each "card" identified by its card number.
        MTs (list): List of reaction types (MT's) present in the ENDF/PENDF files.
    
    Returns:
        None
    """

    # Write the input deck to the groupr.inp file
    with open('groupr.inp', 'w') as f:
        f.write('groupr\n')
        for card_num, card in cards.items():
            f.write(format_card(card_num, card, MTs))
        f.write(' 0/\nstop')

def run_njoy(cards, element, A):
    """
    Use subprocess to run NJOY given a pre-written input card to convert a pair
        of ENDF and PENDF files to a GENDF file and save it locally.
    
    Arguments:
        cards (dict): Dictionary containing each "card" identified by its card number.
        element (str): Chemical symbol for element of interest.
        A (str or int): Mass number for selected isotope.
            If the target is an isomer, "m" after the mass number,
            so A must be input as a string.
    
    Returns:
        gendf_path (str): File path to the newly created GENDF file. 
    """

    # Define the input files
    INPUT = 'groupr.inp'
    OUTPUT = 'groupr.out'

    # Run NJOY
    result = subprocess.run(['njoy'], input=open(INPUT).read(), text=  True, capture_output=True)
    with open(OUTPUT, 'w') as output_file:
        output_file.write(result.stdout)

    # If the run is successful, log out the output and make a copy of the file as a .GENDF file
    if result.stderr == '':
        output = subprocess.run(['cat', 'output'], capture_output=True, text = True)
        title = cards[3][0][1:-1]
        title_index = output.stdout.find(title)
        #print(f'\n{output.stdout[:title_index + len(title)]}\n')

        gendf_path = f'./gendf_files/tendl_2017_{element}{A}.gendf'
        subprocess.run(['cp', 'tape31', gendf_path])
        return gendf_path
    else:
        print(result.stderr)

def njoy_file_cleanup(output_path = 'njoy_ouput'):
    """
    Clean up repository from unnecessary intermediate files from NJOY run.

    Arguments:
        output_path (str): The path where the automated NJOY output will be saved.
            Defaults to 'njoy_output'.
    
    Returns:
        None
    """

    njoy_files = ['groupr.inp', 'groupr.out', 'tape20', 'tape21', 'tape31']
    for file in njoy_files:
        if file == 'groupr.out':
            with open(file, 'r') as f:
                groupr_out = f.read()
            print(groupr_out)
            
        subprocess.run(['rm', file])
    subprocess.run(['mv', 'output', output_path])
    #(f'Full NJOY output file readout can be found at {output_path}')

# %%
import csv
def read_csv(csv_path):
    """
    Read in the mt_table.csv file and store it in a dictionary.
    
    Arguments:
        csv_path (str): File path to mt_table.csv
            This should be in the same repository.
    
    Returns:
        data_dict (dict): Dictionary formatted data structure for mt_table.csv
    """
    mt_dict = {}

    with open(csv_path, 'r') as f:
        csv_reader = csv.DictReader(f)
        for row in csv_reader:
            mt_dict[row['MT']] = row['Reaction']

    return mt_dict

mt_dict = read_csv('mt_table.csv')

# %%
card_deck = groupr_input_file_format(material_id, MTs, 'C', 13, mt_dict)
groupr_input_file_writer(card_deck, MTs)

# %%
run_njoy(card_deck, 'C', 13)
# Out:
# STOP 77

# %%
import numpy as np
#           emitted             delta N       delta P
delta_NP = {'n'     : np.array([-1      ,      0     ]),
            'p'     : np.array([ 0      ,     -1     ]),
            't'     : np.array([-2      ,     -1     ]),
            '3He'   : np.array([-1      ,     -2     ]),
            'α'     : np.array([-2      ,     -2     ]),
}
n,p = delta_NP['n']

# %%
delta_NP.items()
# Out:
# dict_items([('n', array([-1,  0])), ('p', array([ 0, -1])), ('t', array([-2, -1])), ('3He', array([-1, -2])), ('α', array([-2, -2]))])

# %%
from activation_analysis import count_emitted_particles, isomer_check

def emission_breakdown(emitted_particles):
    particle_types = ['n', 'd', 'α', 'p', 't', '3He', 'gamma']
    emission_dict = {
        particle : count_emitted_particles(particle, emitted_particles)
        for particle in particle_types
        if particle in emitted_particles
    }
    return emission_dict

# %%
emission_breakdown('2n24d3He')
# Out:
# {'n': 2, 'd': 24, '3He': 1}

# %%
def nucleon_changes(emission_dict):
    NP_change = np.array([1, 0]) # neutron activation
    
    #           emitted             delta N       delta P
    NP_dict = {'n'     : np.array([-1      ,      0     ]), # neutron emission
                'p'     : np.array([ 0      ,     -1     ]), # proton emission
                'd'     : np.array([-1      ,     -1     ]), # deuteron emission
                't'     : np.array([-2      ,     -1     ]), # triton emission
                '3He'   : np.array([-1      ,     -2     ]), # helium-3 emission
                'α'     : np.array([-2      ,     -2     ]), # alpha particle emission
                }

    for particle, count in emission_dict.items():
        NP_change += count * delta_NP[particle]
        
    return NP_change

# %%
import csv
def load_csv(csv_path):
    """
    Load in the mt_table.csv file and store it in a dictionary.
    
    Arguments:
        csv_path (str): File path to mt_table.csv
            This should be in the same repository.
    
    Returns:
        mt_dict (dict): Dictionary formatted data structure for mt_table.csv
    """
    mt_dict = {}

    with open(csv_path, 'r') as f:
        csv_reader = csv.DictReader(f)
        for row in csv_reader:
            emitted_particles = row['Reaction'].split(',')[1][:-1]
            emission_dict = emission_breakdown(emitted_particles)
            change_N, change_P = nucleon_changes(emission_dict)
            M = isomer_check(emitted_particles)
            mt_dict[row['MT']] = {
                'Reaction' : row['Reaction'],
                'delKZA' : (change_P * 1000 + change_P + change_N) * 10 + M,
                'Emitted Particles' : emitted_particles
            }

    return mt_dict

mt_dict = load_csv('mt_table.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8c5be9cef5c2> in <module>
#      28     return mt_dict
#      29
# ---> 30 mt_dict = load_csv('mt_table.csv')
#
# <ipython-input-1-8c5be9cef5c2> in load_csv(csv_path)
#      17         for row in csv_reader:
#      18             emitted_particles = row['Reaction'].split(',')[1][:-1]
# ---> 19             emission_dict = emission_breakdown(emitted_particles)
#      20             change_N, change_P = nucleon_changes(emission_dict)
#      21             M = isomer_check(emitted_particles)
#
# NameError: name 'emission_breakdown' is not defined

# %%
mt_dict
# Out:
# {'1': {'Reaction': '(n, total)',
#   'delKZA': -10020,
#   'Emitted Particles': ' total'},
#  '2': {'Reaction': '(z,z0)', 'delKZA': 10, 'Emitted Particles': 'z0'},
#  '3': {'Reaction': '(z, nonelas.)',
#   'delKZA': 0,
#   'Emitted Particles': ' nonelas.'},
#  '4': {'Reaction': '(z,n)', 'delKZA': 0, 'Emitted Particles': 'n'},
#  '5': {'Reaction': '(z,anything)',
#   'delKZA': -10030,
#   'Emitted Particles': 'anything'},
#  '10': {'Reaction': '(z,contin.)',
#   'delKZA': -10030,
#   'Emitted Particles': 'contin.'},
#  '11': {'Reaction': '(z,2nd)', 'delKZA': -10030, 'Emitted Particles': '2nd'},
#  '16': {'Reaction': '(z,2n)', 'delKZA': -10, 'Emitted Particles': '2n'},
#  '17': {'Reaction': '(z,3n)', 'delKZA': -20, 'Emitted Particles': '3n'},
#  '18': {'Reaction': '(z,fission)',
#   'delKZA': 0,
#   'Emitted Particles': 'fission'},
#  '19': {'Reaction': '(n,f)', 'delKZA': 10, 'Emitted Particles': 'f'},
#  '20': {'Reaction': '(n,nf)', 'delKZA': 0, 'Emitted Particles': 'nf'},
#  '21': {'Reaction': '(n,2nf)', 'delKZA': -10, 'Emitted Particles': '2nf'},
#  '22': {'Reaction': '(z,nα)', 'delKZA': -20040, 'Emitted Particles': 'nα'},
#  '23': {'Reaction': '(n,n3α)', 'delKZA': -60120, 'Emitted Particles': 'n3α'},
#  '24': {'Reaction': '(z,2nα)', 'delKZA': -20050, 'Emitted Particles': '2nα'},
#  '25': {'Reaction': '(z,3nα)', 'delKZA': -20060, 'Emitted Particles': '3nα'},
#  '27': {'Reaction': '(n,abs)', 'delKZA': 10, 'Emitted Particles': 'abs'},
#  '28': {'Reaction': '(z,np)', 'delKZA': -10010, 'Emitted Particles': 'np'},
#  '29': {'Reaction': '(z,n2α)', 'delKZA': -40080, 'Emitted Particles': 'n2α'},
#  '30': {'Reaction': '(z,2n2α)', 'delKZA': -40090, 'Emitted Particles': '2n2α'},
#  '32': {'Reaction': '(z,nd)', 'delKZA': -10020, 'Emitted Particles': 'nd'},
#  '33': {'Reaction': '(z,nt) ', 'delKZA': -10030, 'Emitted Particles': 'nt)'},
#  '34': {'Reaction': '(z,n3He)', 'delKZA': -20030, 'Emitted Particles': 'n3He'},
#  '35': {'Reaction': '(z,nd2α)', 'delKZA': -50100, 'Emitted Particles': 'nd2α'},
#  '36': {'Reaction': '(z,nt2α)', 'delKZA': -50110, 'Emitted Particles': 'nt2α'},
#  '37': {'Reaction': '(z,4n)', 'delKZA': -30, 'Emitted Particles': '4n'},
#  '38': {'Reaction': '(n,3nf)', 'delKZA': -20, 'Emitted Particles': '3nf'},
#  '41': {'Reaction': '(z,2np)', 'delKZA': -10020, 'Emitted Particles': '2np'},
#  '42': {'Reaction': '(z,3np)', 'delKZA': -10030, 'Emitted Particles': '3np'},
#  '44': {'Reaction': '(z,n2p)', 'delKZA': -20020, 'Emitted Particles': 'n2p'},
#  '45': {'Reaction': '(z,npα)', 'delKZA': -30050, 'Emitted Particles': 'npα'},
#  '50': {'Reaction': '(y,n0)', 'delKZA': 0, 'Emitted Particles': 'n0'},
#  '51': {'Reaction': '(z,n1)', 'delKZA': 1, 'Emitted Particles': 'n1'},
#  '52': {'Reaction': '(z,n2)', 'delKZA': 2, 'Emitted Particles': 'n2'},
#  '53': {'Reaction': '(z,n3)', 'delKZA': 3, 'Emitted Particles': 'n3'},
#  '54': {'Reaction': '(z,n4)', 'delKZA': 4, 'Emitted Particles': 'n4'},
#  '55': {'Reaction': '(z,n5)', 'delKZA': 5, 'Emitted Particles': 'n5'},
#  '56': {'Reaction': '(z,n6)', 'delKZA': 6, 'Emitted Particles': 'n6'},
#  '57': {'Reaction': '(z,n7)', 'delKZA': 7, 'Emitted Particles': 'n7'},
#  '58': {'Reaction': '(z,n8)', 'delKZA': 8, 'Emitted Particles': 'n8'},
#  '59': {'Reaction': '(z,n9)', 'delKZA': 9, 'Emitted Particles': 'n9'},
#  '60': {'Reaction': '(z,n10)', 'delKZA': 10, 'Emitted Particles': 'n10'},
#  '61': {'Reaction': '(z,n11)', 'delKZA': 11, 'Emitted Particles': 'n11'},
#  '62': {'Reaction': '(z,n12)', 'delKZA': 12, 'Emitted Particles': 'n12'},
#  '63': {'Reaction': '(z,n13)', 'delKZA': 13, 'Emitted Particles': 'n13'},
#  '64': {'Reaction': '(z,n14)', 'delKZA': 14, 'Emitted Particles': 'n14'},
#  '65': {'Reaction': '(z,n15)', 'delKZA': 15, 'Emitted Particles': 'n15'},
#  '66': {'Reaction': '(z,n16)', 'delKZA': 16, 'Emitted Particles': 'n16'},
#  '67': {'Reaction': '(z,n17)', 'delKZA': 17, 'Emitted Particles': 'n17'},
#  '68': {'Reaction': '(z,n18)', 'delKZA': 18, 'Emitted Particles': 'n18'},
#  '69': {'Reaction': '(z,n19)', 'delKZA': 19, 'Emitted Particles': 'n19'},
#  '70': {'Reaction': '(z,n20)', 'delKZA': 20, 'Emitted Particles': 'n20'},
#  '71': {'Reaction': '(z,n21)', 'delKZA': 21, 'Emitted Particles': 'n21'},
#  '72': {'Reaction': '(z,n22)', 'delKZA': 22, 'Emitted Particles': 'n22'},
#  '73': {'Reaction': '(z,n23)', 'delKZA': 23, 'Emitted Particles': 'n23'},
#  '74': {'Reaction': '(z,n24)', 'delKZA': 24, 'Emitted Particles': 'n24'},
#  '75': {'Reaction': '(z,n25)', 'delKZA': 25, 'Emitted Particles': 'n25'},
#  '76': {'Reaction': '(z,n26)', 'delKZA': 26, 'Emitted Particles': 'n26'},
#  '77': {'Reaction': '(z,n27)', 'delKZA': 27, 'Emitted Particles': 'n27'},
#  '78': {'Reaction': '(z,n28)', 'delKZA': 28, 'Emitted Particles': 'n28'},
#  '79': {'Reaction': '(z,n29)', 'delKZA': 29, 'Emitted Particles': 'n29'},
#  '80': {'Reaction': '(z,n30)', 'delKZA': 30, 'Emitted Particles': 'n30'},
#  '81': {'Reaction': '(z,n31)', 'delKZA': 31, 'Emitted Particles': 'n31'},
#  '82': {'Reaction': '(z,n32)', 'delKZA': 32, 'Emitted Particles': 'n32'},
#  '83': {'Reaction': '(z,n33)', 'delKZA': 33, 'Emitted Particles': 'n33'},
#  '84': {'Reaction': '(z,n34)', 'delKZA': 34, 'Emitted Particles': 'n34'},
#  '85': {'Reaction': '(z,n35)', 'delKZA': 35, 'Emitted Particles': 'n35'},
#  '86': {'Reaction': '(z,n36)', 'delKZA': 36, 'Emitted Particles': 'n36'},
#  '87': {'Reaction': '(z,n37)', 'delKZA': 37, 'Emitted Particles': 'n37'},
#  '88': {'Reaction': '(z,n38)', 'delKZA': 38, 'Emitted Particles': 'n38'},
#  '89': {'Reaction': '(z,n39)', 'delKZA': 39, 'Emitted Particles': 'n39'},
#  '90': {'Reaction': '(z,n40)', 'delKZA': 40, 'Emitted Particles': 'n40'},
#  '91': {'Reaction': '(z,nc)', 'delKZA': 0, 'Emitted Particles': 'nc'},
#  '101': {'Reaction': '(n,disap)',
#   'delKZA': -20020,
#   'Emitted Particles': 'disap'},
#  '102': {'Reaction': '(z,γ)', 'delKZA': 10, 'Emitted Particles': 'γ'},
#  '103': {'Reaction': '(z,p)', 'delKZA': -10000, 'Emitted Particles': 'p'},
#  '104': {'Reaction': '(z,d)', 'delKZA': -10010, 'Emitted Particles': 'd'},
#  '105': {'Reaction': '(z,t)', 'delKZA': -10020, 'Emitted Particles': 't'},
#  '106': {'Reaction': '(z,3He)', 'delKZA': -20020, 'Emitted Particles': '3He'},
#  '107': {'Reaction': '(z,α)', 'delKZA': -20030, 'Emitted Particles': 'α'},
#  '108': {'Reaction': '(z,2α)', 'delKZA': -40070, 'Emitted Particles': '2α'},
#  '109': {'Reaction': '(z,3α)', 'delKZA': -60110, 'Emitted Particles': '3α'},
#  '111': {'Reaction': '(z,2p)', 'delKZA': -20010, 'Emitted Particles': '2p'},
#  '112': {'Reaction': '(z,pα)', 'delKZA': -30040, 'Emitted Particles': 'pα'},
#  '113': {'Reaction': '(z,t2α)', 'delKZA': -50100, 'Emitted Particles': 't2α'},
#  '114': {'Reaction': '(z,d2α)', 'delKZA': -50090, 'Emitted Particles': 'd2α'},
#  '115': {'Reaction': '(z,pd)', 'delKZA': -20020, 'Emitted Particles': 'pd'},
#  '116': {'Reaction': '(z,pt)', 'delKZA': -20030, 'Emitted Particles': 'pt'},
#  '117': {'Reaction': '(z,dα)', 'delKZA': -30050, 'Emitted Particles': 'dα'},
#  '151': {'Reaction': '(n,RES)', 'delKZA': 10, 'Emitted Particles': 'RES'},
#  '201': {'Reaction': '(z,Xn)', 'delKZA': 0, 'Emitted Particles': 'Xn'},
#  '202': {'Reaction': '(z,Xγ)', 'delKZA': 10, 'Emitted Particles': 'Xγ'},
#  '203': {'Reaction': '(z,Xp)', 'delKZA': -10000, 'Emitted Particles': 'Xp'},
#  '204': {'Reaction': '(z,Xd)', 'delKZA': -10010, 'Emitted Particles': 'Xd'},
#  '205': {'Reaction': '(z,Xt)', 'delKZA': -10020, 'Emitted Particles': 'Xt'},
#  '206': {'Reaction': '(z,X3He)',
#   'delKZA': -20020,
#   'Emitted Particles': 'X3He'},
#  '207': {'Reaction': '(z,Xα)', 'delKZA': -20030, 'Emitted Particles': 'Xα'},
#  '208': {'Reaction': '(z,Xπ +)', 'delKZA': 10, 'Emitted Particles': 'Xπ +'},
#  '209': {'Reaction': '(z,Xπ 0 )', 'delKZA': 10, 'Emitted Particles': 'Xπ 0 '},
#  '210': {'Reaction': '(z,Xπ −)', 'delKZA': 10, 'Emitted Particles': 'Xπ −'},
#  '211': {'Reaction': '(z,Xµ +)', 'delKZA': 10, 'Emitted Particles': 'Xµ +'},
#  '212': {'Reaction': '(z,Xµ −)', 'delKZA': 10, 'Emitted Particles': 'Xµ −'},
#  '213': {'Reaction': '(z,Xκ +)', 'delKZA': 10, 'Emitted Particles': 'Xκ +'},
#  '214': {'Reaction': '(z,Xκ 0 long)',
#   'delKZA': 0,
#   'Emitted Particles': 'Xκ 0 long'},
#  '215': {'Reaction': '(z,Xκ 0 short)',
#   'delKZA': -10020,
#   'Emitted Particles': 'Xκ 0 short'},
#  '216': {'Reaction': '(z,Xκ −)', 'delKZA': 10, 'Emitted Particles': 'Xκ −'},
#  '217': {'Reaction': '(z,Xp−)', 'delKZA': -10000, 'Emitted Particles': 'Xp−'},
#  '218': {'Reaction': '(z,Xn−)', 'delKZA': 0, 'Emitted Particles': 'Xn−'},
#  '251': {'Reaction': '(n,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '252': {'Reaction': '(n,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '253': {'Reaction': '(n,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '301': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '302': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '303': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '304': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '305': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '306': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '307': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '308': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '309': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '310': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '311': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '312': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '313': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '314': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '315': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '316': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '317': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '318': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '319': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '320': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '321': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '322': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '323': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '324': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '325': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '326': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '327': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '328': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '329': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '330': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '331': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '332': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '333': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '334': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '335': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '336': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '337': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '338': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '339': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '340': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '341': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '342': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '343': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '344': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '345': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '346': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '347': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '348': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '349': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '350': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '351': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '352': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '353': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '354': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '355': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '356': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '357': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '358': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '359': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '360': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '361': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '362': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '363': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '364': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '365': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '366': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '367': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '368': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '369': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '370': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '371': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '372': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '373': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '374': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '375': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '376': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '377': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '378': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '379': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '380': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '381': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '382': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '383': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '384': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '385': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '386': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '387': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '388': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '389': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '390': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '391': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '392': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '393': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '394': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '395': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '396': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '397': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '398': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '399': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '400': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '401': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '402': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '403': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '404': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '405': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '406': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '407': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '408': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '409': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '410': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '411': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '412': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '413': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '414': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '415': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '416': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '417': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '418': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '419': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '420': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '421': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '422': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '423': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '424': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '425': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '426': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '427': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '428': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '429': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '430': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '431': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '432': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '433': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '434': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '435': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '436': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '437': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '438': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '439': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '440': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '441': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '442': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '443': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '444': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '445': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '446': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '447': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '448': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '449': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '450': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '451': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '452': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '454': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '455': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '456': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '457': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '458': {'Reaction': '(n,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '459': {'Reaction': '(z,...)', 'delKZA': 10, 'Emitted Particles': '...'},
#  '600': {'Reaction': '(z,p0)', 'delKZA': -10000, 'Emitted Particles': 'p0'},
#  '601': {'Reaction': '(z,p1)', 'delKZA': -9999, 'Emitted Particles': 'p1'},
#  '602': {'Reaction': '(z,p2)', 'delKZA': -9998, 'Emitted Particles': 'p2'},
#  '603': {'Reaction': '(z,p3)', 'delKZA': -9997, 'Emitted Particles': 'p3'},
#  '604': {'Reaction': '(z,p4)', 'delKZA': -9996, 'Emitted Particles': 'p4'},
#  '605': {'Reaction': '(z,p5)', 'delKZA': -9995, 'Emitted Particles': 'p5'},
#  '606': {'Reaction': '(z,p6)', 'delKZA': -9994, 'Emitted Particles': 'p6'},
#  '607': {'Reaction': '(z,p7)', 'delKZA': -9993, 'Emitted Particles': 'p7'},
#  '608': {'Reaction': '(z,p8)', 'delKZA': -9992, 'Emitted Particles': 'p8'},
#  '609': {'Reaction': '(z,p9)', 'delKZA': -9991, 'Emitted Particles': 'p9'},
#  '610': {'Reaction': '(z,p10)', 'delKZA': -9990, 'Emitted Particles': 'p10'},
#  '611': {'Reaction': '(z,p11)', 'delKZA': -9989, 'Emitted Particles': 'p11'},
#  '612': {'Reaction': '(z,p12)', 'delKZA': -9988, 'Emitted Particles': 'p12'},
#  '613': {'Reaction': '(z,p13)', 'delKZA': -9987, 'Emitted Particles': 'p13'},
#  '614': {'Reaction': '(z,p14)', 'delKZA': -9986, 'Emitted Particles': 'p14'},
#  '615': {'Reaction': '(z,p15)', 'delKZA': -9985, 'Emitted Particles': 'p15'},
#  '616': {'Reaction': '(z,p16)', 'delKZA': -9984, 'Emitted Particles': 'p16'},
#  '617': {'Reaction': '(z,p17)', 'delKZA': -9983, 'Emitted Particles': 'p17'},
#  '618': {'Reaction': '(z,p18)', 'delKZA': -9982, 'Emitted Particles': 'p18'},
#  '619': {'Reaction': '(z,p19)', 'delKZA': -9981, 'Emitted Particles': 'p19'},
#  '620': {'Reaction': '(z,p20)', 'delKZA': -9980, 'Emitted Particles': 'p20'},
#  '621': {'Reaction': '(z,p21)', 'delKZA': -9979, 'Emitted Particles': 'p21'},
#  '622': {'Reaction': '(z,p22)', 'delKZA': -9978, 'Emitted Particles': 'p22'},
#  '623': {'Reaction': '(z,p23)', 'delKZA': -9977, 'Emitted Particles': 'p23'},
#  '624': {'Reaction': '(z,p24)', 'delKZA': -9976, 'Emitted Particles': 'p24'},
#  '625': {'Reaction': '(z,p25)', 'delKZA': -9975, 'Emitted Particles': 'p25'},
#  '626': {'Reaction': '(z,p26)', 'delKZA': -9974, 'Emitted Particles': 'p26'},
#  '627': {'Reaction': '(z,p27)', 'delKZA': -9973, 'Emitted Particles': 'p27'},
#  '628': {'Reaction': '(z,p28)', 'delKZA': -9972, 'Emitted Particles': 'p28'},
#  '629': {'Reaction': '(z,p29)', 'delKZA': -9971, 'Emitted Particles': 'p29'},
#  '630': {'Reaction': '(z,p30)', 'delKZA': -9970, 'Emitted Particles': 'p30'},
#  '631': {'Reaction': '(z,p31)', 'delKZA': -9969, 'Emitted Particles': 'p31'},
#  '632': {'Reaction': '(z,p32)', 'delKZA': -9968, 'Emitted Particles': 'p32'},
#  '633': {'Reaction': '(z,p33)', 'delKZA': -9967, 'Emitted Particles': 'p33'},
#  '634': {'Reaction': '(z,p34)', 'delKZA': -9966, 'Emitted Particles': 'p34'},
#  '635': {'Reaction': '(z,p35)', 'delKZA': -9965, 'Emitted Particles': 'p35'},
#  '636': {'Reaction': '(z,p36)', 'delKZA': -9964, 'Emitted Particles': 'p36'},
#  '637': {'Reaction': '(z,p37)', 'delKZA': -9963, 'Emitted Particles': 'p37'},
#  '638': {'Reaction': '(z,p38)', 'delKZA': -9962, 'Emitted Particles': 'p38'},
#  '639': {'Reaction': '(z,p39)', 'delKZA': -9961, 'Emitted Particles': 'p39'},
#  '640': {'Reaction': '(z,p40)', 'delKZA': -9960, 'Emitted Particles': 'p40'},
#  '641': {'Reaction': '(z,p41)', 'delKZA': -9959, 'Emitted Particles': 'p41'},
#  '642': {'Reaction': '(z,p42)', 'delKZA': -9958, 'Emitted Particles': 'p42'},
#  '643': {'Reaction': '(z,p43)', 'delKZA': -9957, 'Emitted Particles': 'p43'},
#  '644': {'Reaction': '(z,p44)', 'delKZA': -9956, 'Emitted Particles': 'p44'},
#  '645': {'Reaction': '(z,p45)', 'delKZA': -9955, 'Emitted Particles': 'p45'},
#  '646': {'Reaction': '(z,p46)', 'delKZA': -9954, 'Emitted Particles': 'p46'},
#  '647': {'Reaction': '(z,p47)', 'delKZA': -9953, 'Emitted Particles': 'p47'},
#  '648': {'Reaction': '(z,p48)', 'delKZA': -9952, 'Emitted Particles': 'p48'},
#  '649': {'Reaction': '(z,pc)', 'delKZA': -10000, 'Emitted Particles': 'pc'},
#  '650': {'Reaction': '(z,d0)', 'delKZA': -10010, 'Emitted Particles': 'd0'},
#  '651': {'Reaction': '(z,d1)', 'delKZA': -10009, 'Emitted Particles': 'd1'},
#  '652': {'Reaction': '(z,d2)', 'delKZA': -10008, 'Emitted Particles': 'd2'},
#  '653': {'Reaction': '(z,d3)', 'delKZA': -10007, 'Emitted Particles': 'd3'},
#  '654': {'Reaction': '(z,d4)', 'delKZA': -10006, 'Emitted Particles': 'd4'},
#  '655': {'Reaction': '(z,d5)', 'delKZA': -10005, 'Emitted Particles': 'd5'},
#  '656': {'Reaction': '(z,d6)', 'delKZA': -10004, 'Emitted Particles': 'd6'},
#  '657': {'Reaction': '(z,d7)', 'delKZA': -10003, 'Emitted Particles': 'd7'},
#  '658': {'Reaction': '(z,d8)', 'delKZA': -10002, 'Emitted Particles': 'd8'},
#  '659': {'Reaction': '(z,d9)', 'delKZA': -10001, 'Emitted Particles': 'd9'},
#  '660': {'Reaction': '(z,d10)', 'delKZA': -10000, 'Emitted Particles': 'd10'},
#  '661': {'Reaction': '(z,d11)', 'delKZA': -9999, 'Emitted Particles': 'd11'},
#  '662': {'Reaction': '(z,d12)', 'delKZA': -9998, 'Emitted Particles': 'd12'},
#  '663': {'Reaction': '(z,d13)', 'delKZA': -9997, 'Emitted Particles': 'd13'},
#  '664': {'Reaction': '(z,d14)', 'delKZA': -9996, 'Emitted Particles': 'd14'},
#  '665': {'Reaction': '(z,d15)', 'delKZA': -9995, 'Emitted Particles': 'd15'},
#  '666': {'Reaction': '(z,d16)', 'delKZA': -9994, 'Emitted Particles': 'd16'},
#  '667': {'Reaction': '(z,d17)', 'delKZA': -9993, 'Emitted Particles': 'd17'},
#  '668': {'Reaction': '(z,d18)', 'delKZA': -9992, 'Emitted Particles': 'd18'},
#  '669': {'Reaction': '(z,d19)', 'delKZA': -9991, 'Emitted Particles': 'd19'},
#  '670': {'Reaction': '(z,d20)', 'delKZA': -9990, 'Emitted Particles': 'd20'},
#  '671': {'Reaction': '(z,d21)', 'delKZA': -9989, 'Emitted Particles': 'd21'},
#  '672': {'Reaction': '(z,d22)', 'delKZA': -9988, 'Emitted Particles': 'd22'},
#  '673': {'Reaction': '(z,d23)', 'delKZA': -9987, 'Emitted Particles': 'd23'},
#  '674': {'Reaction': '(z,d24)', 'delKZA': -9986, 'Emitted Particles': 'd24'},
#  '675': {'Reaction': '(z,d25)', 'delKZA': -9985, 'Emitted Particles': 'd25'},
#  '676': {'Reaction': '(z,d26)', 'delKZA': -9984, 'Emitted Particles': 'd26'},
#  '677': {'Reaction': '(z,d27)', 'delKZA': -9983, 'Emitted Particles': 'd27'},
#  '678': {'Reaction': '(z,d28)', 'delKZA': -9982, 'Emitted Particles': 'd28'},
#  '679': {'Reaction': '(z,d29)', 'delKZA': -9981, 'Emitted Particles': 'd29'},
#  '680': {'Reaction': '(z,d30)', 'delKZA': -9980, 'Emitted Particles': 'd30'},
#  '681': {'Reaction': '(z,d31)', 'delKZA': -9979, 'Emitted Particles': 'd31'},
#  '682': {'Reaction': '(z,d32)', 'delKZA': -9978, 'Emitted Particles': 'd32'},
#  '683': {'Reaction': '(z,d33)', 'delKZA': -9977, 'Emitted Particles': 'd33'},
#  '684': {'Reaction': '(z,d34)', 'delKZA': -9976, 'Emitted Particles': 'd34'},
#  '685': {'Reaction': '(z,d35)', 'delKZA': -9975, 'Emitted Particles': 'd35'},
#  '686': {'Reaction': '(z,d36)', 'delKZA': -9974, 'Emitted Particles': 'd36'},
#  '687': {'Reaction': '(z,d37)', 'delKZA': -9973, 'Emitted Particles': 'd37'},
#  '688': {'Reaction': '(z,d38)', 'delKZA': -9972, 'Emitted Particles': 'd38'},
#  '689': {'Reaction': '(z,d39)', 'delKZA': -9971, 'Emitted Particles': 'd39'},
#  '690': {'Reaction': '(z,d40)', 'delKZA': -9970, 'Emitted Particles': 'd40'},
#  '691': {'Reaction': '(z,d41)', 'delKZA': -9969, 'Emitted Particles': 'd41'},
#  '692': {'Reaction': '(z,d42)', 'delKZA': -9968, 'Emitted Particles': 'd42'},
#  '693': {'Reaction': '(z,d43)', 'delKZA': -9967, 'Emitted Particles': 'd43'},
#  '694': {'Reaction': '(z,d44)', 'delKZA': -9966, 'Emitted Particles': 'd44'},
#  '695': {'Reaction': '(z,d45)', 'delKZA': -9965, 'Emitted Particles': 'd45'},
#  '696': {'Reaction': '(z,d46)', 'delKZA': -9964, 'Emitted Particles': 'd46'},
#  '697': {'Reaction': '(z,d47)', 'delKZA': -9963, 'Emitted Particles': 'd47'},
#  '698': {'Reaction': '(z,d48)', 'delKZA': -9962, 'Emitted Particles': 'd48'},
#  '699': {'Reaction': '(z,dc)', 'delKZA': -10010, 'Emitted Particles': 'dc'},
#  '700': {'Reaction': '(z,t0)', 'delKZA': -10020, 'Emitted Particles': 't0'},
#  '701': {'Reaction': '(z,t1)', 'delKZA': -10019, 'Emitted Particles': 't1'},
#  '702': {'Reaction': '(z,t2)', 'delKZA': -10018, 'Emitted Particles': 't2'},
#  '703': {'Reaction': '(z,t3)', 'delKZA': -10017, 'Emitted Particles': 't3'},
#  '704': {'Reaction': '(z,t4)', 'delKZA': -10016, 'Emitted Particles': 't4'},
#  '705': {'Reaction': '(z,t5)', 'delKZA': -10015, 'Emitted Particles': 't5'},
#  '706': {'Reaction': '(z,t6)', 'delKZA': -10014, 'Emitted Particles': 't6'},
#  '707': {'Reaction': '(z,t7)', 'delKZA': -10013, 'Emitted Particles': 't7'},
#  '708': {'Reaction': '(z,t8)', 'delKZA': -10012, 'Emitted Particles': 't8'},
#  '709': {'Reaction': '(z,t9)', 'delKZA': -10011, 'Emitted Particles': 't9'},
#  '710': {'Reaction': '(z,t10)', 'delKZA': -10010, 'Emitted Particles': 't10'},
#  '711': {'Reaction': '(z,t11)', 'delKZA': -10009, 'Emitted Particles': 't11'},
#  '712': {'Reaction': '(z,t12)', 'delKZA': -10008, 'Emitted Particles': 't12'},
#  '713': {'Reaction': '(z,t13)', 'delKZA': -10007, 'Emitted Particles': 't13'},
#  '714': {'Reaction': '(z,t14)', 'delKZA': -10006, 'Emitted Particles': 't14'},
#  '715': {'Reaction': '(z,t15)', 'delKZA': -10005, 'Emitted Particles': 't15'},
#  '716': {'Reaction': '(z,t16)', 'delKZA': -10004, 'Emitted Particles': 't16'},
#  '717': {'Reaction': '(z,t17)', 'delKZA': -10003, 'Emitted Particles': 't17'},
#  '718': {'Reaction': '(z,t18)', 'delKZA': -10002, 'Emitted Particles': 't18'},
#  '719': {'Reaction': '(z,t19)', 'delKZA': -10001, 'Emitted Particles': 't19'},
#  '720': {'Reaction': '(z,t20)', 'delKZA': -10000, 'Emitted Particles': 't20'},
#  '721': {'Reaction': '(z,t21)', 'delKZA': -9999, 'Emitted Particles': 't21'},
#  '722': {'Reaction': '(z,t22)', 'delKZA': -9998, 'Emitted Particles': 't22'},
#  '723': {'Reaction': '(z,t23)', 'delKZA': -9997, 'Emitted Particles': 't23'},
#  '724': {'Reaction': '(z,t24)', 'delKZA': -9996, 'Emitted Particles': 't24'},
#  '725': {'Reaction': '(z,t25)', 'delKZA': -9995, 'Emitted Particles': 't25'},
#  '726': {'Reaction': '(z,t26)', 'delKZA': -9994, 'Emitted Particles': 't26'},
#  '727': {'Reaction': '(z,t27)', 'delKZA': -9993, 'Emitted Particles': 't27'},
#  '728': {'Reaction': '(z,t28)', 'delKZA': -9992, 'Emitted Particles': 't28'},
#  '729': {'Reaction': '(z,t29)', 'delKZA': -9991, 'Emitted Particles': 't29'},
#  '730': {'Reaction': '(z,t30)', 'delKZA': -9990, 'Emitted Particles': 't30'},
#  '731': {'Reaction': '(z,t31)', 'delKZA': -9989, 'Emitted Particles': 't31'},
#  '732': {'Reaction': '(z,t32)', 'delKZA': -9988, 'Emitted Particles': 't32'},
#  '733': {'Reaction': '(z,t33)', 'delKZA': -9987, 'Emitted Particles': 't33'},
#  '734': {'Reaction': '(z,t34)', 'delKZA': -9986, 'Emitted Particles': 't34'},
#  '735': {'Reaction': '(z,t35)', 'delKZA': -9985, 'Emitted Particles': 't35'},
#  '736': {'Reaction': '(z,t36)', 'delKZA': -9984, 'Emitted Particles': 't36'},
#  '737': {'Reaction': '(z,t37)', 'delKZA': -9983, 'Emitted Particles': 't37'},
#  '738': {'Reaction': '(z,t38)', 'delKZA': -9982, 'Emitted Particles': 't38'},
#  '739': {'Reaction': '(z,t39)', 'delKZA': -9981, 'Emitted Particles': 't39'},
#  '740': {'Reaction': '(z,t40)', 'delKZA': -9980, 'Emitted Particles': 't40'},
#  '741': {'Reaction': '(z,t41)', 'delKZA': -9979, 'Emitted Particles': 't41'},
#  '742': {'Reaction': '(z,t42)', 'delKZA': -9978, 'Emitted Particles': 't42'},
#  '743': {'Reaction': '(z,t43)', 'delKZA': -9977, 'Emitted Particles': 't43'},
#  '744': {'Reaction': '(z,t44)', 'delKZA': -9976, 'Emitted Particles': 't44'},
#  '745': {'Reaction': '(z,t45)', 'delKZA': -9975, 'Emitted Particles': 't45'},
#  '746': {'Reaction': '(z,t46)', 'delKZA': -9974, 'Emitted Particles': 't46'},
#  '747': {'Reaction': '(z,t47)', 'delKZA': -9973, 'Emitted Particles': 't47'},
#  '748': {'Reaction': '(z,t48)', 'delKZA': -9972, 'Emitted Particles': 't48'},
#  '749': {'Reaction': '(z,tc) ', 'delKZA': -10020, 'Emitted Particles': 'tc)'},
#  '750': {'Reaction': '(n,3He0)',
#   'delKZA': -20020,
#   'Emitted Particles': '3He0'},
#  '751': {'Reaction': '(z,3He1)',
#   'delKZA': -20019,
#   'Emitted Particles': '3He1'},
#  '752': {'Reaction': '(z,3He2)',
#   'delKZA': -20018,
#   'Emitted Particles': '3He2'},
#  '753': {'Reaction': '(z,3He3)',
#   'delKZA': -20017,
#   'Emitted Particles': '3He3'},
#  '754': {'Reaction': '(z,3He4)',
#   'delKZA': -20016,
#   'Emitted Particles': '3He4'},
#  '755': {'Reaction': '(z,3He5)',
#   'delKZA': -20015,
#   'Emitted Particles': '3He5'},
#  '756': {'Reaction': '(z,3He6)',
#   'delKZA': -20014,
#   'Emitted Particles': '3He6'},
#  '757': {'Reaction': '(z,3He7)',
#   'delKZA': -20013,
#   'Emitted Particles': '3He7'},
#  '758': {'Reaction': '(z,3He8)',
#   'delKZA': -20012,
#   'Emitted Particles': '3He8'},
#  '759': {'Reaction': '(z,3He9)',
#   'delKZA': -20011,
#   'Emitted Particles': '3He9'},
#  '760': {'Reaction': '(z,3He10)',
#   'delKZA': -20010,
#   'Emitted Particles': '3He10'},
#  '761': {'Reaction': '(z,3He11)',
#   'delKZA': -20009,
#   'Emitted Particles': '3He11'},
#  '762': {'Reaction': '(z,3He12)',
#   'delKZA': -20008,
#   'Emitted Particles': '3He12'},
#  '763': {'Reaction': '(z,3He13)',
#   'delKZA': -20007,
#   'Emitted Particles': '3He13'},
#  '764': {'Reaction': '(z,3He14)',
#   'delKZA': -20006,
#   'Emitted Particles': '3He14'},
#  '765': {'Reaction': '(z,3He15)',
#   'delKZA': -20005,
#   'Emitted Particles': '3He15'},
#  '766': {'Reaction': '(z,3He16)',
#   'delKZA': -20004,
#   'Emitted Particles': '3He16'},
#  '767': {'Reaction': '(z,3He17)',
#   'delKZA': -20003,
#   'Emitted Particles': '3He17'},
#  '768': {'Reaction': '(z,3He18)',
#   'delKZA': -20002,
#   'Emitted Particles': '3He18'},
#  '769': {'Reaction': '(z,3He19)',
#   'delKZA': -20001,
#   'Emitted Particles': '3He19'},
#  '770': {'Reaction': '(z,3He20)',
#   'delKZA': -20000,
#   'Emitted Particles': '3He20'},
#  '771': {'Reaction': '(z,3He21)',
#   'delKZA': -19999,
#   'Emitted Particles': '3He21'},
#  '772': {'Reaction': '(z,3He22)',
#   'delKZA': -19998,
#   'Emitted Particles': '3He22'},
#  '773': {'Reaction': '(z,3He23)',
#   'delKZA': -19997,
#   'Emitted Particles': '3He23'},
#  '774': {'Reaction': '(z,3He24)',
#   'delKZA': -19996,
#   'Emitted Particles': '3He24'},
#  '775': {'Reaction': '(z,3He25)',
#   'delKZA': -19995,
#   'Emitted Particles': '3He25'},
#  '776': {'Reaction': '(z,3He26)',
#   'delKZA': -19994,
#   'Emitted Particles': '3He26'},
#  '777': {'Reaction': '(z,3He27)',
#   'delKZA': -19993,
#   'Emitted Particles': '3He27'},
#  '778': {'Reaction': '(z,3He28)',
#   'delKZA': -19992,
#   'Emitted Particles': '3He28'},
#  '779': {'Reaction': '(z,3He29)',
#   'delKZA': -19991,
#   'Emitted Particles': '3He29'},
#  '780': {'Reaction': '(z,3He30)',
#   'delKZA': -19990,
#   'Emitted Particles': '3He30'},
#  '781': {'Reaction': '(z,3He31)',
#   'delKZA': -19989,
#   'Emitted Particles': '3He31'},
#  '782': {'Reaction': '(z,3He32)',
#   'delKZA': -19988,
#   'Emitted Particles': '3He32'},
#  '783': {'Reaction': '(z,3He33)',
#   'delKZA': -19987,
#   'Emitted Particles': '3He33'},
#  '784': {'Reaction': '(z,3He34)',
#   'delKZA': -19986,
#   'Emitted Particles': '3He34'},
#  '785': {'Reaction': '(z,3He35)',
#   'delKZA': -19985,
#   'Emitted Particles': '3He35'},
#  '786': {'Reaction': '(z,3He36)',
#   'delKZA': -19984,
#   'Emitted Particles': '3He36'},
#  '787': {'Reaction': '(z,3He37)',
#   'delKZA': -19983,
#   'Emitted Particles': '3He37'},
#  '788': {'Reaction': '(z,3He38)',
#   'delKZA': -19982,
#   'Emitted Particles': '3He38'},
#  '789': {'Reaction': '(z,3He39)',
#   'delKZA': -19981,
#   'Emitted Particles': '3He39'},
#  '790': {'Reaction': '(z,3He40)',
#   'delKZA': -19980,
#   'Emitted Particles': '3He40'},
#  '791': {'Reaction': '(z,3He41)',
#   'delKZA': -19979,
#   'Emitted Particles': '3He41'},
#  '792': {'Reaction': '(z,3He42)',
#   'delKZA': -19978,
#   'Emitted Particles': '3He42'},
#  '793': {'Reaction': '(z,3He43)',
#   'delKZA': -19977,
#   'Emitted Particles': '3He43'},
#  '794': {'Reaction': '(z,3He44)',
#   'delKZA': -19976,
#   'Emitted Particles': '3He44'},
#  '795': {'Reaction': '(z,3He45)',
#   'delKZA': -19975,
#   'Emitted Particles': '3He45'},
#  '796': {'Reaction': '(z,3He46)',
#   'delKZA': -19974,
#   'Emitted Particles': '3He46'},
#  '797': {'Reaction': '(z,3He47)',
#   'delKZA': -19973,
#   'Emitted Particles': '3He47'},
#  '798': {'Reaction': '(z,3He48)',
#   'delKZA': -19972,
#   'Emitted Particles': '3He48'},
#  '799': {'Reaction': '(n,3Hec)',
#   'delKZA': -20020,
#   'Emitted Particles': '3Hec'},
#  '800': {'Reaction': '(z,α0)', 'delKZA': -20030, 'Emitted Particles': 'α0'},
#  '801': {'Reaction': '(z,α1)', 'delKZA': -20029, 'Emitted Particles': 'α1'},
#  '802': {'Reaction': '(z,α2)', 'delKZA': -20028, 'Emitted Particles': 'α2'},
#  '803': {'Reaction': '(z,α3)', 'delKZA': -20027, 'Emitted Particles': 'α3'},
#  '804': {'Reaction': '(z,α4)', 'delKZA': -20026, 'Emitted Particles': 'α4'},
#  '805': {'Reaction': '(z,α5)', 'delKZA': -20025, 'Emitted Particles': 'α5'},
#  '806': {'Reaction': '(z,α6)', 'delKZA': -20024, 'Emitted Particles': 'α6'},
#  '807': {'Reaction': '(z,α7)', 'delKZA': -20023, 'Emitted Particles': 'α7'},
#  '808': {'Reaction': '(z,α8)', 'delKZA': -20022, 'Emitted Particles': 'α8'},
#  '809': {'Reaction': '(z,α9)', 'delKZA': -20021, 'Emitted Particles': 'α9'},
#  '810': {'Reaction': '(z,α10)', 'delKZA': -20020, 'Emitted Particles': 'α10'},
#  '811': {'Reaction': '(z,α11)', 'delKZA': -20019, 'Emitted Particles': 'α11'},
#  '812': {'Reaction': '(z,α12)', 'delKZA': -20018, 'Emitted Particles': 'α12'},
#  '813': {'Reaction': '(z,α13)', 'delKZA': -20017, 'Emitted Particles': 'α13'},
#  '814': {'Reaction': '(z,α14)', 'delKZA': -20016, 'Emitted Particles': 'α14'},
#  '815': {'Reaction': '(z,α15)', 'delKZA': -20015, 'Emitted Particles': 'α15'},
#  '816': {'Reaction': '(z,α16)', 'delKZA': -20014, 'Emitted Particles': 'α16'},
#  '817': {'Reaction': '(z,α17)', 'delKZA': -20013, 'Emitted Particles': 'α17'},
#  '818': {'Reaction': '(z,α18)', 'delKZA': -20012, 'Emitted Particles': 'α18'},
#  '819': {'Reaction': '(z,α19)', 'delKZA': -20011, 'Emitted Particles': 'α19'},
#  '820': {'Reaction': '(z,α20)', 'delKZA': -20010, 'Emitted Particles': 'α20'},
#  '821': {'Reaction': '(z,α21)', 'delKZA': -20009, 'Emitted Particles': 'α21'},
#  '822': {'Reaction': '(z,α22)', 'delKZA': -20008, 'Emitted Particles': 'α22'},
#  '823': {'Reaction': '(z,α23)', 'delKZA': -20007, 'Emitted Particles': 'α23'},
#  '824': {'Reaction': '(z,α24)', 'delKZA': -20006, 'Emitted Particles': 'α24'},
#  '825': {'Reaction': '(z,α25)', 'delKZA': -20005, 'Emitted Particles': 'α25'},
#  '826': {'Reaction': '(z,α26)', 'delKZA': -20004, 'Emitted Particles': 'α26'},
#  '827': {'Reaction': '(z,α27)', 'delKZA': -20003, 'Emitted Particles': 'α27'},
#  '828': {'Reaction': '(z,α28)', 'delKZA': -20002, 'Emitted Particles': 'α28'},
#  '829': {'Reaction': '(z,α29)', 'delKZA': -20001, 'Emitted Particles': 'α29'},
#  '830': {'Reaction': '(z,α30)', 'delKZA': -20000, 'Emitted Particles': 'α30'},
#  '831': {'Reaction': '(z,α31)', 'delKZA': -19999, 'Emitted Particles': 'α31'},
#  '832': {'Reaction': '(z,α32)', 'delKZA': -19998, 'Emitted Particles': 'α32'},
#  '833': {'Reaction': '(z,α33)', 'delKZA': -19997, 'Emitted Particles': 'α33'},
#  '834': {'Reaction': '(z,α34)', 'delKZA': -19996, 'Emitted Particles': 'α34'},
#  '835': {'Reaction': '(z,α35)', 'delKZA': -19995, 'Emitted Particles': 'α35'},
#  '836': {'Reaction': '(z,α36)', 'delKZA': -19994, 'Emitted Particles': 'α36'},
#  '837': {'Reaction': '(z,α37)', 'delKZA': -19993, 'Emitted Particles': 'α37'},
#  '838': {'Reaction': '(z,α38)', 'delKZA': -19992, 'Emitted Particles': 'α38'},
#  '839': {'Reaction': '(z,α39)', 'delKZA': -19991, 'Emitted Particles': 'α39'},
#  '840': {'Reaction': '(z,α40)', 'delKZA': -19990, 'Emitted Particles': 'α40'},
#  '841': {'Reaction': '(z,α41)', 'delKZA': -19989, 'Emitted Particles': 'α41'},
#  '842': {'Reaction': '(z,α42)', 'delKZA': -19988, 'Emitted Particles': 'α42'},
#  '843': {'Reaction': '(z,α43)', 'delKZA': -19987, 'Emitted Particles': 'α43'},
#  '844': {'Reaction': '(z,α44)', 'delKZA': -19986, 'Emitted Particles': 'α44'},
#  '845': {'Reaction': '(z,α45)', 'delKZA': -19985, 'Emitted Particles': 'α45'},
#  '846': {'Reaction': '(z,α46)', 'delKZA': -19984, 'Emitted Particles': 'α46'},
#  '847': {'Reaction': '(z,α47)', 'delKZA': -19983, 'Emitted Particles': 'α47'},
#  '848': {'Reaction': '(z,α48)', 'delKZA': -19982, 'Emitted Particles': 'α48'},
#  '849': {'Reaction': '(z,αc) ', 'delKZA': -20030, 'Emitted Particles': 'αc)'},
#  '875': {'Reaction': '(z,2n0)', 'delKZA': -10, 'Emitted Particles': '2n0'},
#  '876': {'Reaction': '(z,2n1)', 'delKZA': -9, 'Emitted Particles': '2n1'},
#  '877': {'Reaction': '(z,2n2)', 'delKZA': -8, 'Emitted Particles': '2n2'},
#  '878': {'Reaction': '(z,2n3)', 'delKZA': -7, 'Emitted Particles': '2n3'},
#  '879': {'Reaction': '(z,2n4)', 'delKZA': -6, 'Emitted Particles': '2n4'},
#  '880': {'Reaction': '(z,2n5)', 'delKZA': -5, 'Emitted Particles': '2n5'},
#  '881': {'Reaction': '(z,2n6)', 'delKZA': -4, 'Emitted Particles': '2n6'},
#  '882': {'Reaction': '(z,2n7)', 'delKZA': -3, 'Emitted Particles': '2n7'},
#  '883': {'Reaction': '(z,2n8)', 'delKZA': -2, 'Emitted Particles': '2n8'},
#  '884': {'Reaction': '(z,2n9)', 'delKZA': -1, 'Emitted Particles': '2n9'},
#  '885': {'Reaction': '(z,2n10)', 'delKZA': 0, 'Emitted Particles': '2n10'},
#  '886': {'Reaction': '(z,2n11)', 'delKZA': 1, 'Emitted Particles': '2n11'},
#  '887': {'Reaction': '(z,2n12)', 'delKZA': 2, 'Emitted Particles': '2n12'},
#  '888': {'Reaction': '(z,2n13)', 'delKZA': 3, 'Emitted Particles': '2n13'},
#  '889': {'Reaction': '(z,2n14)', 'delKZA': 4, 'Emitted Particles': '2n14'},
#  '890': {'Reaction': '(z,2n15)', 'delKZA': 5, 'Emitted Particles': '2n15'},
#  '891': {'Reaction': '(z,2nc)', 'delKZA': -10, 'Emitted Particles': '2nc'}}

# %%
mt_dict['11'].keys()
# Out:
# dict_keys(['Reaction', 'delKZA', 'Emitted Particles'])

# %%
MT = 11
mt_dict[str(MT)]['Reaction']
# Out:
# '(z,2nd)'

# %%
pKZA = 260560
dKZA = pKZA + delKZA
dKZA
# Out:
# 230510

# %%
nuclear_decay({'n': 1, 'α': 1, 'p': 1})
# Out:
# array([-3, -3])

# %%
Z = 26
A = 56
n = A - Z
M = 0
KZA = (Z * 1000 + Z + n) * 10 + M
KZA
# Out:
# 260560

# %%
A = '56M for tendl 2017                                              0 0  0    0'
A.lower().split(' ')[0].split('m')[0]
# Out:
# '56'

# %%
MT3_FEND = '                                                                  2631 0  0    0'

# %%
spaces = '                                                                  '
len(spaces)
# Out:
# 66

# %%
' ' * 66 == spaces
# Out:
# True

# %%
gendf_path = '/filespace/e/esweinstein2/ALARA/src/DataLib/fendl32B_retrofit/gendf_files/tendl_2017_Fe56.gendf'
whitespace = ' ' * 66
matd = str(2631)
with open(gendf_path, 'r') as gendf_file:
    file_str = gendf_file.read()
identifier = f'{matd} 1451   '
mf1_last_line = file_str.rfind(identifier)
file_str[mf1_last_line + len(identifier):mf1_last_line + len(identifier) + 2]
new_line = f'{whitespace}{matd} 1 0'
with open(gendf_path, 'w') as gendf_file:
# Out:
# '                                                                  2631 1 0'

# %%
gendf_path = '/filespace/e/esweinstein2/ALARA/src/DataLib/fendl32B_retrofit/gendf_files/tendl_2017_Fe56.gendf'
whitespace = ' ' * 66
matb = str(2631)

# Read the file content
with open(gendf_path, 'r') as gendf_file:
    file_str = gendf_file.read()

mf1_identifier = f'{matb} 1451   '
mf3_identifier = f'{matb} 3  099999'
mf1_last_line_index = file_str.rfind(mf1_identifier)
mf3_SEND_RECORD_index = file_str.rfind(mf3_identifier)

# Prepare the new line
mf1_SEND_RECORD = f'{whitespace}{matb} 1  099999'
mf3_FEND_RECORD = f'{whitespace}{matb} 0  0    0'

# Calculate the end position of the identified line
end_of_identifier_line = file_str.find('\n', mf1_last_line_index) + 1

# Split the file content into lines
file_lines = file_str.splitlines()

# Find the line number of the identified line
line_number = file_str[:mf1_last_line_index].count('\n')

# Insert the new line after the identified line
file_lines.insert(line_number + 1, mf1_SEND_RECORD)

# Join the lines back into a single string
new_file_str = '\n'.join(file_lines) + '\n'

# Write the updated content back to the file
with open(gendf_path, 'w') as gendf_file:
    gendf_file.write(new_file_str)

# %%
gendf_path = '/filespace/e/esweinstein2/ALARA/src/DataLib/fendl32B_retrofit/gendf_files/tendl_2017_Fe56.gendf'
matb = str(2631)
whitespace = ' ' * 66

# Define identifiers and corresponding new lines
mf1_identifier = f'{matb} 1451   '
mf3_identifier = f'{matb} 3  099999'
mf1_SEND_RECORD = f'{whitespace}{matb} 1  099999'
mf3_FEND_RECORD = f'{whitespace}{matb} 0  0    0'

# Store identifiers and new lines in lists
identifiers = [mf1_identifier, mf3_identifier]
new_lines = [mf1_SEND_RECORD, mf3_FEND_RECORD]

# Read the file content
with open(gendf_path, 'r') as gendf_file:
    file_str = gendf_file.read()

# Initialize a list to hold modified file lines
file_lines = file_str.splitlines()

# Iterate over each identifier and corresponding new line
for identifier, new_line in zip(identifiers, new_lines):
    last_line_index = file_str.rfind(identifier)
    
    # Calculate the end position of the identified line
    end_of_identifier_line = file_str.find('\n', last_line_index) + 1

    # Find the line number of the identified line
    line_number = file_str[:last_line_index].count('\n')

    # Insert the new line after the identified line
    file_lines.insert(line_number + 1, new_line)

# Join the lines back into a single string
new_file_str = '\n'.join(file_lines) + '\n'

# Write the updated content back to the file
with open(gendf_path, 'w') as gendf_file:
    gendf_file.write(new_file_str)

# %%
def ensure_gendf_markers(gendf_path, matb):
    """
    Edit the GENDF files produced from an NJOY GROUPR run to include file and
    section records that are not automatically written out to the file by
    NJOY. Missing these records will not cause errors, but will raise
    messages when they are read by ENDFtk, which expects these markers, so
    this method ensures that they are present. Edits will only be made if
    the SEND record for MF1 or the FEND record for MF3 are not present.
    The formatting for these records can be found at:
    https://t2.lanl.gov/nis/endf/intro06.html

    Arguments:
        gendf_path (str): File path to the newly created GENDF file.
        matb (int): Unique material ID for the material in the GENDF file.
    
    Returns:
        None
    """

    # In ENDF-6 formatted files, there are 66 lines of whitespace before
    # the values in record-keeping lines
    whitespace = ' ' * 66

    # Define identifiers with original variable names
    mf1_identifier = f'{matb} 1451   '
    mf3_identifier = f'{matb} 3  099999'

    # Define new lines with original variable names
    mf1_SEND_RECORD = f'{whitespace}{matb} 1  099999'
    mf3_FEND_RECORD = f'{whitespace}{matb} 0  0    0'

    updates = [
        (mf3_identifier, mf3_FEND_RECORD),
        (mf1_identifier, mf1_SEND_RECORD)
    ]

    with open(gendf_path, 'r') as gendf_file:
        file_str = gendf_file.read()

    file_lines = file_str.splitlines()

    for identifier, new_line in updates:
        if identifier not in file_str:
            last_line_index = file_str.rfind(identifier)
            end_of_identifier_line = file_str.find('\n', last_line_index) + 1
            line_number = file_str[:last_line_index].count('\n')
            file_lines.insert(line_number + 1, new_line)

    new_file_str = '\n'.join(file_lines) + '\n'

    with open(gendf_path, 'w') as gendf_file:
        gendf_file.write(new_file_str)
ensure_gendf_markers('/filespace/e/esweinstein2/ALARA/src/DataLib/fendl32B_retrofit/gendf_files/tendl_2017_Ti48m.gendf', 2232)

# %%
help(zip)
# Out:
# Help on class zip in module builtins:
#
# class zip(object)
#  |  zip(*iterables) --> A zip object yielding tuples until an input is exhausted.
#  |
#  |     >>> list(zip('abcdefg', range(3), range(4)))
#  |     [('a', 0, 0), ('b', 1, 1), ('c', 2, 2)]
#  |
#  |  The zip object yields n-length tuples, where n is the number of iterables
#  |  passed as positional arguments to zip().  The i-th element in every tuple
#  |  comes from the i-th iterable argument to zip().  This continues until the
#  |  shortest argument is exhausted.
#  |
#  |  Methods defined here:
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __next__(self, /)
#  |      Implement next(self).
#  |
#  |  __reduce__(...)
#  |      Return state information for pickling.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.

# %%
import requests
from bs4 import BeautifulSoup

def fetch_and_parse_html(url):
    # Send a GET request to the URL
    response = requests.get(url)
    
    # Check if the request was successful
    if response.status_code != 200:
        raise Exception(f"Failed to fetch the webpage. Status code: {response.status_code}")
    
    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Print the title of the webpage
    title = soup.title.string if soup.title else 'No title found'
    print(f"Title of the webpage: {title}")
    
    # Find all <a> tags and extract the href attributes
    links = soup.find_all('a')
    urls = [link.get('href') for link in links if link.get('href')]
    
    # Print all found URLs
    for i, url in enumerate(urls, 1):
        print(f"URL {i}: {url}")
    
    # Return the list of URLs
    return urls

# Example usage
url = 'https://tendl.web.psi.ch/tendl_2017/neutron_html/Be/NeutronBe07.html'
urls = fetch_and_parse_html(url)
# Out:
# Title of the webpage: Neutron sub-library - TENDL-2017
# URL 1: NeutronBe07angle.html
# URL 2: NeutronBe07angle1.html
# URL 3: NeutronBe07gamma.html
# URL 4: NeutronBe07residual.html
# URL 5: NeutronBe07spectra.html
# URL 6: NeutronBe07xs.html
# URL 7: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/n-Be007.tendl
# URL 8: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/n-Be007.pendf
# URL 9: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/n-Be007.ace.gz
# URL 10: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/n-Be007.xsdir
# URL 11: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endfs20/n-Be007-s20.tendl
# URL 12: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/eaf/n-Be007-eaf.tendl
# URL 13: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/eaf/n-Be007-eaf.tendl_cov
# URL 14: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/acf/n-Be007-acf.tendl
# URL 15: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/plots/n-Be007-njoy-plots.pdf
# URL 16: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/plots/n-Be007-pointwise-tendl.pdf
# URL 17: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/plots/n-Be007-endfb8.0-comp.pdf
# URL 18: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/plots/n-Be007-njoy-cov-187g.all.300.K.matrix
# URL 19: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/plots/n-Be007-njoy-cov-187g.cross.300.K.pdf
# URL 20: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/plots/n-Be007-njoy-cov-44g.all.300.K.matrix
# URL 21: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/plots/n-Be007-njoy-cov-44g.cross.300.K.pdf
# URL 22: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/plots/n-Be007-njoy-cov-33g.all.300.K.matrix
# URL 23: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/plots/n-Be007-njoy-cov-33g.cross.300.K.pdf
# URL 24: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/plots/n-Be007-njoy-cov-187g.angle.300.K.matrix
# URL 25: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/plots/n-Be007-njoy-cov-187g.angle.300.K.pdf
# URL 26: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/plots/n-Be007-njoy-cov-33g.angle.300.K.matrix
# URL 27: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/plots/n-Be007-njoy-cov-33g.angle.300.K.pdf
# URL 28: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/input/acf.inp
# URL 29: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/input/acf.inp_cov
# URL 30: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/input/eaf.inp
# URL 31: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/input/eaf.inp_cov
# URL 32: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/input/energies
# URL 33: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/input/gpf.inp
# URL 34: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/input/gpf.inp_cov
# URL 35: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/input/gpfmt.inp
# URL 36: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/input/gpfmt.inp_cov
# URL 37: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/input/gpfs20.inp
# URL 38: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/input/gpfs20.inp_cov
# URL 39: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/input/gpfs60.inp
# URL 40: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/input/gpfs60.inp_cov
# URL 41: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/input/njoy.inp
# URL 42: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/input/talys.inp
# URL 43: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/input/talys.inp.0000
# URL 44: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/input/talys.inp.0001
# URL 45: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/input/talys.inp.0002
# URL 46: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/input/talys.inp.0003
# URL 47: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/input/talys.inp.0004
# URL 48: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/input/talys.inp.0005
# URL 49: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/input/talys.inp.0006
# URL 50: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/input/talys.inp.0007
# URL 51: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/input/talys.inp.0008
# URL 52: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/input/talys.inp.0009
# URL 53: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/input/talys.inp.0010
# URL 54: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/input/talys.inp.9999
# URL 55: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/input/tasman.inp
# URL 56: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/random/n-Be007-rand-0000.ace.gz
# URL 57: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/random/n-Be007-rand-0000.gz
# URL 58: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/input/talys.inp.0000
# URL 59: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/random/n-Be007-rand-0000.xsdir.gz
# URL 60: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/random/n-Be007-rand-0001.ace.gz
# URL 61: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/random/n-Be007-rand-0001.gz
# URL 62: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/input/talys.inp.0001
# URL 63: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/random/n-Be007-rand-0001.xsdir.gz
# URL 64: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/random/n-Be007-rand-0002.ace.gz
# URL 65: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/random/n-Be007-rand-0002.gz
# URL 66: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/input/talys.inp.0002
# URL 67: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/random/n-Be007-rand-0002.xsdir.gz
# URL 68: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/random/n-Be007-rand-0003.ace.gz
# URL 69: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/random/n-Be007-rand-0003.gz
# URL 70: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/input/talys.inp.0003
# URL 71: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/random/n-Be007-rand-0003.xsdir.gz
# URL 72: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/random/n-Be007-rand-0004.ace.gz
# URL 73: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/random/n-Be007-rand-0004.gz
# URL 74: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/input/talys.inp.0004
# URL 75: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/random/n-Be007-rand-0004.xsdir.gz
# URL 76: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/random/n-Be007-rand-0005.ace.gz
# URL 77: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/random/n-Be007-rand-0005.gz
# URL 78: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/input/talys.inp.0005
# URL 79: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/random/n-Be007-rand-0005.xsdir.gz
# URL 80: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/random/n-Be007-rand-0006.ace.gz
# URL 81: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/random/n-Be007-rand-0006.gz
# URL 82: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/input/talys.inp.0006
# URL 83: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/random/n-Be007-rand-0006.xsdir.gz
# URL 84: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/random/n-Be007-rand-0007.ace.gz
# URL 85: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/random/n-Be007-rand-0007.gz
# URL 86: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/input/talys.inp.0007
# URL 87: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/random/n-Be007-rand-0007.xsdir.gz
# URL 88: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/random/n-Be007-rand-0008.ace.gz
# URL 89: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/random/n-Be007-rand-0008.gz
# URL 90: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/input/talys.inp.0008
# URL 91: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/random/n-Be007-rand-0008.xsdir.gz
# URL 92: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/random/n-Be007-rand-0009.ace.gz
# URL 93: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/random/n-Be007-rand-0009.gz
# URL 94: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/input/talys.inp.0009
# URL 95: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/random/n-Be007-rand-0009.xsdir.gz
# URL 96: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/random/n-Be007-rand-0010.ace.gz
# URL 97: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/random/n-Be007-rand-0010.gz
# URL 98: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/input/talys.inp.0010
# URL 99: https://tendl.web.psi.ch/tendl_2017/neutron_file/Be/Be007/lib/endf/random/n-Be007-rand-0010.xsdir.gz

# %%
TENDL_GEN_URL = 'https://tendl.web.psi.ch/tendl_2017'
element = 'Be'

for A in range(1,292):
    for i in range(2):
        A_str = str(A).zfill(3)
        if i == 1:
            A_str += 'm'
        
        navigation_page_url = f'{TENDL_GEN_URL}/neutron_html/{element}/Neutron{element}{str(A).zfill(2)}.html'
        isotope_component = f'/neutron_file/{element}/{element}{A_str}/lib/endf/n-{element}{A_str}.'
        tendl_url = TENDL_GEN_URL + isotope_component + 'tendl'
        pendf_url = TENDL_GEN_URL + isotope_component + 'pendf'
        
        nav_urls = fetch_and_parse_html(navigation_page_url)

        if tendl_url in nav_urls and pendf_url in nav_urls:
            print(A_str)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-6-6b1be269c0e6> in <module>
#      13         pendf_url = TENDL_GEN_URL + isotope_component + 'pendf'
#      14
# ---> 15         nav_urls = fetch_and_parse_html(navigation_page_url)
#      16
#      17         if tendl_url in nav_urls and pendf_url in nav_urls:
#
# <ipython-input-3-9534d8fa5754> in fetch_and_parse_html(url)
#       8     # Check if the request was successful
#       9     if response.status_code != 200:
# ---> 10         raise Exception(f"Failed to fetch the webpage. Status code: {response.status_code}")
#      11
#      12     # Parse the HTML content using BeautifulSoup
#
# Exception: Failed to fetch the webpage. Status code: 404

# %%
import subprocess

element = 'Fe'
# Run the command
gendf_files = subprocess.run(f'ls gendf_files/*{element}*',
                        shell=True,
                        check=True,
                        stdout=subprocess.PIPE,
                        universal_newlines=True)
#            ).stdout.strip().split("\n")

# Print the output
print(gendf_files.stdout)
# Out:
# gendf_files/tendl_2017_Fe052.gendf
# gendf_files/tendl_2017_Fe052m.gendf
# gendf_files/tendl_2017_Fe053.gendf
# gendf_files/tendl_2017_Fe053m.gendf
# gendf_files/tendl_2017_Fe054.gendf
# gendf_files/tendl_2017_Fe055.gendf
# gendf_files/tendl_2017_Fe056.gendf
# gendf_files/tendl_2017_Fe057.gendf
# gendf_files/tendl_2017_Fe058.gendf
# gendf_files/tendl_2017_Fe059.gendf
# gendf_files/tendl_2017_Fe060.gendf
# gendf_files/tendl_2017_Fe061.gendf
# gendf_files/tendl_2017_Fe062.gendf
# gendf_files/tendl_2017_Fe063.gendf
# gendf_files/tendl_2017_Fe064.gendf
# gendf_files/tendl_2017_Fe065m.gendf
# gendf_files/tendl_2017_Fe56.gendf

# %%
import os
dir = './gendf_files'
os.path.isdir(dir)
# Out:
# True

# %%
subprocess.CalledProcessError(returncode= 2, cmd='ls')
# Out:
# subprocess.CalledProcessError()

# %%
path = 'gendf_files/tendl_2017_Fe052.gendf '
element = 'Fe'
element_index = path.rfind(element)
ext_index = path.find('.gendf')
A = path[element_index + len(element): ext_index]
A
# Out:
# '052'

# %%
import os

gendf_dir = './gendf_files'

if gendf_dir:
    print("success")
# Out:
# success

# %%
from logging_config import logger
import logging

logger.handlers.pop?
# Out:
# Signature: logger.handlers.pop(index=-1, /)
# Docstring:
# Remove and return item at index (default last).
#
# Raises IndexError if list is empty or index is out of range.
# Type:      builtin_function_or_method

# %%
79 - len('2024-07-15 15:21:17,929 - INFO All files:')
# Out:
# 38

# %%
# Dictionary of elements in the Periodic Table
elements = [
    'H', 'He', 'Li', 'Be', 'B', 'C', 'N', 'O', 'F', 'Ne',
    'Na', 'Mg', 'Al', 'Si', 'P', 'S', 'Cl', 'Ar', 'K', 'Ca',
    'Sc', 'Ti', 'V', 'Cr', 'Mn', 'Fe', 'Co', 'Ni', 'Cu', 'Zn',
    'Ga', 'Ge', 'As', 'Se', 'Br', 'Kr', 'Rb', 'Sr', 'Y', 'Zr',
    'Nb', 'Mo', 'Tc', 'Ru', 'Rh', 'Pd', 'Ag', 'Cd', 'In', 'Sn',
    'Sb', 'Te', 'I', 'Xe', 'Cs', 'Ba', 'La', 'Ce', 'Pr', 'Nd',
    'Pm', 'Sm', 'Eu', 'Gd', 'Tb', 'Dy', 'Ho', 'Er', 'Tm', 'Yb',
    'Lu', 'Hf', 'Ta', 'W', 'Re', 'Os', 'Ir', 'Pt', 'Au', 'Hg',
    'Tl', 'Pb', 'Bi', 'Po', 'At', 'Rn', 'Fr', 'Ra', 'Ac', 'Th',
    'Pa', 'U', 'Np', 'Pu', 'Am', 'Cm', 'Bk', 'Cf', 'Es', 'Fm',
    'Md', 'No', 'Lr', 'Rf', 'Db', 'Sg', 'Bh', 'Hs', 'Mt', 'Ds',
    'Rg', 'Cn', 'Nh', 'Fl', 'Mc', 'Lv', 'Ts', 'Og'
]
elements = dict(zip(elements, range(1, len(elements)+1)))
{v: k for k, v in elements.items()}
elements.keys()
# Out:
# dict_keys(['H', 'He', 'Li', 'Be', 'B', 'C', 'N', 'O', 'F', 'Ne', 'Na', 'Mg', 'Al', 'Si', 'P', 'S', 'Cl', 'Ar', 'K', 'Ca', 'Sc', 'Ti', 'V', 'Cr', 'Mn', 'Fe', 'Co', 'Ni', 'Cu', 'Zn', 'Ga', 'Ge', 'As', 'Se', 'Br', 'Kr', 'Rb', 'Sr', 'Y', 'Zr', 'Nb', 'Mo', 'Tc', 'Ru', 'Rh', 'Pd', 'Ag', 'Cd', 'In', 'Sn', 'Sb', 'Te', 'I', 'Xe', 'Cs', 'Ba', 'La', 'Ce', 'Pr', 'Nd', 'Pm', 'Sm', 'Eu', 'Gd', 'Tb', 'Dy', 'Ho', 'Er', 'Tm', 'Yb', 'Lu', 'Hf', 'Ta', 'W', 'Re', 'Os', 'Ir', 'Pt', 'Au', 'Hg', 'Tl', 'Pb', 'Bi', 'Po', 'At', 'Rn', 'Fr', 'Ra', 'Ac', 'Th', 'Pa', 'U', 'Np', 'Pu', 'Am', 'Cm', 'Bk', 'Cf', 'Es', 'Fm', 'Md', 'No', 'Lr', 'Rf', 'Db', 'Sg', 'Bh', 'Hs', 'Mt', 'Ds', 'Rg', 'Cn', 'Nh', 'Fl', 'Mc', 'Lv', 'Ts', 'Og'])

# %%
from numpy import array

NP_dict   = {'n'     : array([-1      ,      0      ]), # neutron emission
             'p'     : array([ 0      ,     -1      ]), # proton emission
             'd'     : array([-1      ,     -1      ]), # deuteron emission
             't'     : array([-2      ,     -1      ]), # triton emission
             '3He'   : array([-1      ,     -2      ]), # helium-3 emission
             'α'     : array([-2      ,     -2      ]), # alpha emission
}

for particle in NP_dict.keys():
    print(particle)
# Out:
# n
# p
# d
# t
# 3He
# α

# %%
from pathlib import Path

save_directory = Path('./gendf_files')

if not save_directory.exists():
    save_directory.mkdir(parents=True)

# %%
str(Path.cwd()) + '/mt_table.csv'
# Out:
# '/filespace/e/esweinstein2/ALARA/src/DataLib/fendl32B_retrofit/mt_table.csv'

# %%
directory_dict = {
    'same' : '',
    'daug' : 'fendl32B_retrofit'
}

f'{directory_dict["daug"]}/mt_table.csv'
# Out:
# 'fendl32B_retrofit/mt_table.csv'

# %%
Path.exists(Path('mt_table.csv'))
# Out:
# True

# %%
import csv

def process_mt_table(csv_path):
    """
    Load in the mt_table.csv file which contains Table B.1 -
        "Reaction Type Numbers MT" from the ENDF-6 manual which can be found
        at https://www.oecd-nea.org/dbdata/data/manual-endf/endf102_MT.pdf.
        Given this, calculate the resultant change in KZA associated with each
        MT value in the table and tally the particle emissions associated with
        these reactions. Store all of this data in a dictionary of the format:
        {'MT' : {'Reaction' : (z , emission),
                 'delKZA' : change_in_KZA,
                 'Emitted Particles' : string_of_particles
                }
        }
    
    Arguments:
        csv_path (str): File path to mt_table.csv
            This should be in the same repository.
    
    Returns:
        mt_dict (dict): Dictionary formatted data structure for mt_table.csv,
            along with changes in KZA and emitted_particles.
    """
    csv_path = 'csv_path'
    mt_dict = {}

    with open(csv_path, 'r') as f:
        csv_reader = csv.DictReader(f)
        for row in csv_reader:
            mt_dict[row['MT']] = row['Reaction'].split(',')[1][:-1]

    return mt_dict

# %%
from string import Template

s = Template('$who likes $what')
s.substitute(who='tim', what = 'kung pao')
type(s)
# Out:
# string.Template

# %%
from groupr_tools import groupr_static_template, format_card
from string import Template

string = 'groupr\n'
for card_num, card in groupr_static_template().items():
    string += format_card(card_num, card, 11)
string += ' 0/\nstop'
print(string)
# Out:
# groupr
#  20 21 0 31/
#  17 0 11 0 1 1 1/
#  /
#  293.16
#  0/
#  /
#  0/
#  0/
# stop

# %%
from string import Template
x = 'j $t'
s = Template(
    """
    text
    new line
    title
    """
)
title_index = s.template.find('title')
s.template[title_index : title_index + len('title')]
# Out:
# 27

# %%
elements = [
    'H', 'He', 'Li', 'Be', 'B', 'C', 'N', 'O', 'F', 'Ne',
    'Na', 'Mg', 'Al', 'Si', 'P', 'S', 'Cl', 'Ar', 'K', 'Ca',
    'Sc', 'Ti', 'V', 'Cr', 'Mn', 'Fe', 'Co', 'Ni', 'Cu', 'Zn',
    'Ga', 'Ge', 'As', 'Se', 'Br', 'Kr', 'Rb', 'Sr', 'Y', 'Zr',
    'Nb', 'Mo', 'Tc', 'Ru', 'Rh', 'Pd', 'Ag', 'Cd', 'In', 'Sn',
    'Sb', 'Te', 'I', 'Xe', 'Cs', 'Ba', 'La', 'Ce', 'Pr', 'Nd',
    'Pm', 'Sm', 'Eu', 'Gd', 'Tb', 'Dy', 'Ho', 'Er', 'Tm', 'Yb',
    'Lu', 'Hf', 'Ta', 'W', 'Re', 'Os', 'Ir', 'Pt', 'Au', 'Hg',
    'Tl', 'Pb', 'Bi', 'Po', 'At', 'Rn', 'Fr', 'Ra', 'Ac', 'Th',
    'Pa', 'U', 'Np', 'Pu', 'Am', 'Cm', 'Bk', 'Cf', 'Es', 'Fm',
    'Md', 'No', 'Lr', 'Rf', 'Db', 'Sg', 'Bh', 'Hs', 'Mt', 'Ds',
    'Rg', 'Cn', 'Nh', 'Fl', 'Mc', 'Lv', 'Ts', 'Og'
]
elements = dict(zip(elements, range(1, len(elements)+1)))

# %%
MFD = 3
from groupr_tools import establish_static_template

def fill_input_template(material_id, MTs, element, A, mt_dict, template):
    Z = str(elements[element]).zfill(2)
    title = f'"{Z}-{element}-{A} for TENDL 2017"'
    card9_lines = []

    for MT in MTs:
        mtname = mt_dict[str(MT)]['Reaction']
        card9_lines.append(f'{MFD} {MT} "{mtname}" /')
    card9 = '\n '.join(card9_lines).drop
    print(template.substitute(mat_id = material_id, title = title, reactions = card9))

    return template

import reaction_data as rxd
mt_dict = rxd.process_mt_data(rxd.load_mt_table('mt_table.csv'))
input_template = establish_static_template()
input_template = fill_input_template(125, [1,11,54], 'Fe', 56, mt_dict, input_template)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-28-2dc649ae71b7> in <module>
#       1 MFD = 3
# ----> 2 from groupr_tools import establish_static_template
#       3
#       4 def fill_input_template(material_id, MTs, element, A, mt_dict, template):
#       5     Z = str(elements[element]).zfill(2)
#
# ImportError: cannot import name 'establish_static_template' from 'groupr_tools' (/filespace/e/esweinstein2/ALARA/src/DataLib/fendl32B_retrofit/groupr_tools.py)
